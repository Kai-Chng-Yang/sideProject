# %%
'''import pandas as pd
df = pd.read_csv('taipei_season.csv')#每月
df['季節'].unique()
dict1 = {'冬季':1, '春雨':2, '梅雨':3, '夏季':4, '秋季':5}
df['季節'].replace(dict1, inplace=True)
df1 = df[['平均氣溫[0C]','平均相對溼度[%]','日照時數[小時]','降水量[毫米]','降水日數[日]']]
df1.corr()'''

# %%
import pandas as pd
avg = pd.read_csv('taipei_season_average.csv')#各季
avg['季節'].unique()
dict1 = {'冬季':1, '春雨':2, '梅雨':3, '夏季':4, '秋季':5}
avg['季節'].replace(dict1, inplace=True)
avg = avg[['年分','季節','平均氣溫[0C]','平均相對溼度[%]','日照時數[小時]','降水量[毫米]','降水日數[日]']]
avg.head()
# Out:
#     年分  季節  平均氣溫[0C]  平均相對溼度[%]  日照時數[小時]     降水量[毫米]  降水日數[日]
# 0  102   1      17.3         76      76.6  141.200000       16
# 1  102   2      19.9         73      80.4  112.166667       12
# 2  102   3      27.6         71      92.7  270.750000       16
# 3  102   4      29.0         68     170.1  397.433333       11
# 4  102   5      22.7         68      93.9   74.200000       12

# %%
select_avg = avg[['平均氣溫[0C]','平均相對溼度[%]','日照時數[小時]','降水量[毫米]','降水日數[日]']]
select_avg.corr()
# Out:
#            平均氣溫[0C]  平均相對溼度[%]  日照時數[小時]   降水量[毫米]   降水日數[日]
# 平均氣溫[0C]   1.000000  -0.366481  0.741818  0.594675  0.062422
# 平均相對溼度[%] -0.366481   1.000000 -0.533891  0.047211  0.277739
# 日照時數[小時]   0.741818  -0.533891  1.000000  0.208112 -0.318206
# 降水量[毫米]    0.594675   0.047211  0.208112  1.000000  0.604925
# 降水日數[日]    0.062422   0.277739 -0.318206  0.604925  1.000000

# %%
#年分
avg_102 = avg[avg['年分']==102]
avg_103 = avg[avg['年分']==103]
avg_104 = avg[avg['年分']==104]
avg_105 = avg[avg['年分']==105]
avg_106 = avg[avg['年分']==106]
avg_107 = avg[avg['年分']==107]
avg_108 = avg[avg['年分']==108]
avg_109 = avg[avg['年分']==109]
avg_110 = avg[avg['年分']==110]
avg_111 = avg[avg['年分']==111]
avg_112 = avg[avg['年分']==112]

# %%
#季節
avg_1 = avg[avg['季節']==1]
avg_2 = avg[avg['季節']==2]
avg_3 = avg[avg['季節']==3]
avg_4 = avg[avg['季節']==4]
avg_5 = avg[avg['季節']==5]

# %%
'''import matplotlib.pyplot as plt 

listx = [1,2,3,4,5]
season_102 = avg_102['季節']
tem_102 = avg_102['平均氣溫[0C]']
plt.plot(season_102, tem_102,color="red", lw="2.0", ls="--", label="102")
season_111 = avg_111['季節']
tem_111 = avg_111['平均氣溫[0C]']
plt.plot(season_111, tem_111,color="blue", lw="2.0", ls="--", label="111")
plt.title("102&111 tem comparison", fontsize=20)  # 圖表標題
plt.xlabel('season', fontsize=12)
plt.ylabel("tem", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')
plt.legend()
plt.show()
'''

# %%
'''
import matplotlib.pyplot as plt 

listx = [1,2,3,4,5]
season_102 = avg_102['季節']
rh_102 = avg_102['平均相對溼度[%]']
plt.plot(season_102, tem_102,color="red",marker='o', lw="2.0", ls="--", label="102")
season_111 = avg_111['季節']
rh_111 = avg_111['平均相對溼度[%]']
plt.plot(season_111, tem_111,color="blue",marker='o', lw="2.0", ls="--", label="111")
plt.title("rh comparison", fontsize=20)  # 圖表標題
plt.xlabel('season', fontsize=12)
plt.ylabel("relative humidity", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')
plt.legend()
plt.show()

'''

# %%
year_1 = avg_1['年分']
tem_1 = avg_1['平均氣溫[0C]']
rh_1 = avg_1['平均相對溼度[%]']
rf_1 = avg_1['降水量[毫米]']
year_2 = avg_2['年分']
tem_2 = avg_2['平均氣溫[0C]']
rh_2 = avg_2['平均相對溼度[%]']
rf_2 = avg_2['降水量[毫米]']
year_3 = avg_3['年分']
tem_3 = avg_3['平均氣溫[0C]']
rh_3 = avg_3['平均相對溼度[%]']
rf_3 = avg_3['降水量[毫米]']
year_4 = avg_4['年分']
tem_4 = avg_4['平均氣溫[0C]']
rh_4 = avg_4['平均相對溼度[%]']
rf_4 = avg_4['降水量[毫米]']
year_5 = avg_5['年分']
tem_5 = avg_5['平均氣溫[0C]']
rh_5 = avg_5['平均相對溼度[%]']
rf_5 = avg_5['降水量[毫米]']

# %%
#wwinter
import matplotlib.pyplot as plt

plt.figure(figsize=[15,15])
listx = [102,103,104,105,106,107,108,109,110,111,112]

#平均氣溫
plt.subplot(5,3,1)
plt.plot(year_1, tem_1,color="red", lw="2.0", ls="--")
plt.title("tem_Winter", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("tem", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

#平均相對溼度
plt.subplot(5,3,2)
plt.plot(year_1, rh_1,color="red", lw="2.0", ls="--")
plt.title("rh_Winter", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("relative humidity", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

#降水量
plt.subplot(5,3,3)
plt.plot(year_1, rf_1,color="red", lw="2.0", ls="--")
plt.title("rf_Winter", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("rainfall", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#spring
import matplotlib.pyplot as plt

plt.figure(figsize=[15,15])
listx = [102,103,104,105,106,107,108,109,110,111,112]

plt.subplot(5,3,1)
plt.plot(year_2, tem_2,color="red", lw="2.0", ls="--")
plt.title("tem_Spring", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("tem", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

#平均相對溼度
plt.subplot(5,3,2)
plt.plot(year_2, rh_2,color="red", lw="2.0", ls="--")
plt.title("rh_Spring", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("relative humidity", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

#降水量
plt.subplot(5,3,3)
plt.plot(year_2, rf_2,color="red", lw="2.0", ls="--")
plt.title("rf_Spring", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("rainfall", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#rainy season
import matplotlib.pyplot as plt

plt.figure(figsize=[15,15])
listx = [102,103,104,105,106,107,108,109,110,111,112]

plt.subplot(5,3,1)
plt.plot(year_3, tem_3,color="red", lw="2.0", ls="--")
plt.title("tem_RainySeason", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("tem", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

#平均相對溼度
plt.subplot(5,3,2)
plt.plot(year_3, rh_3,color="red", lw="2.0", ls="--")
plt.title("rh_RainySeason", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("relative humidity", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

#降水量
plt.subplot(5,3,3)
plt.plot(year_3, rf_3,color="red", lw="2.0", ls="--")
plt.title("rf_RainySeason", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("rainfall", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Summer
import matplotlib.pyplot as plt

plt.figure(figsize=[15,15])
listx = [102,103,104,105,106,107,108,109,110,111,112]

plt.subplot(5,3,1)
plt.plot(year_4, tem_4,color="red", lw="2.0", ls="--")
plt.title("tem_Summer", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("tem", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

#平均相對溼度
plt.subplot(5,3,2)
plt.plot(year_4, rh_4,color="red", lw="2.0", ls="--")
plt.title("rh_Summer", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("relative humidity", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

#降水量
plt.subplot(5,3,3)
plt.plot(year_4, rf_4,color="red", lw="2.0", ls="--")
plt.title("rf_Summer", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("rainfall", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Autumn
import matplotlib.pyplot as plt

plt.figure(figsize=[15,15])
listx = [102,103,104,105,106,107,108,109,110,111,112]

plt.subplot(5,3,1)
plt.plot(year_5, tem_5,color="red", lw="2.0", ls="--")
plt.title("tem_Autumn", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("tem", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

#平均相對溼度
plt.subplot(5,3,2)
plt.plot(year_5, rh_5,color="red", lw="2.0", ls="--")
plt.title("rh_Autumn", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("relative humidity", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')

#降水量
plt.subplot(5,3,3)
plt.plot(year_4, rf_4,color="red", lw="2.0", ls="--")
plt.title("rf_Autumn", fontsize=14)
plt.xlabel('year', fontsize=12)
plt.ylabel("rainfall", fontsize=12)
plt.xticks(listx)
plt.tick_params(axis='both')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.pairplot(select_avg)
# Out:
# c:\Users\fox\Documents\sideProject\venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\fox\Documents\sideProject\venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\fox\Documents\sideProject\venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 27683 (\N{CJK UNIFIED IDEOGRAPH-6C23}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\fox\Documents\sideProject\venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 28331 (\N{CJK UNIFIED IDEOGRAPH-6EAB}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
select_avg = avg[['平均氣溫[0C]','平均相對溼度[%]','日照時數[小時]','降水量[毫米]','降水日數[日]']]
select_avg.corr()
# Out:
#            平均氣溫[0C]  平均相對溼度[%]  日照時數[小時]   降水量[毫米]   降水日數[日]
# 平均氣溫[0C]   1.000000  -0.366481  0.741818  0.594675  0.062422
# 平均相對溼度[%] -0.366481   1.000000 -0.533891  0.047211  0.277739
# 日照時數[小時]   0.741818  -0.533891  1.000000  0.208112 -0.318206
# 降水量[毫米]    0.594675   0.047211  0.208112  1.000000  0.604925
# 降水日數[日]    0.062422   0.277739 -0.318206  0.604925  1.000000
